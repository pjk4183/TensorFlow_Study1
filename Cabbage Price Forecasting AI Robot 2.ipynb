# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

import numpy as np

X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([4,1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

hypothesis = tf.matmul(X,W)  + b

saver = tf.train.Saver() #저장된 모델을 초기화
model = tf.global_variables_initializer()

#user input
avg_temp = float(input('평균 온도: '))
min_temp = float(input('최저 온도: '))
max_temp = float(input('최고 온도: '))
rain_fall = float(input('강수량: '))
# Out:
# 평균 온도: 10
# 최저 온도: -5
# 최고 온도: 20
# 강수량: 0.8

# %%
with tf.Session() as sess: 
    sess.run(model) #모델에 적용한 값을 출력
    
    save_path = "./saved.cpkt" #저장된 학습 모델
    saver.restore(sess, save_path) #해당 session에 저장된 학습 모델을 불러옴
    
    data = ((avg_temp, min_temp, max_temp, rain_fall),) #user input을 이용하여 2차원 배열을 생성
    arr = np.array(data, dtype=np.float32) 
    
    x_data = arr[0:4]
    dict = sess.run(hypothesis, feed_dict={X: x_data})
    print(dict[0])
# Out:
# INFO:tensorflow:Restoring parameters from ./saved.cpkt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# E:\Jupyter\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#
# E:\Jupyter\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358       self._extend_graph()
# -> 1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1360                                       target_list, run_metadata)
#
# E:\Jupyter\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1450                           run_metadata):
# -> 1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
#
# NotFoundError: Key bias_10 not found in checkpoint
# 	 [[{{node save_11/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1296       else:
# -> 1297         sess.run(self.saver_def.restore_op_name,
#    1298                  {self.saver_def.filename_tensor_name: save_path})
#
# E:\Jupyter\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#
# E:\Jupyter\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190       results = self._do_run(handle, final_targets, final_fetches,
#    1191                              feed_dict_tensor, options, run_metadata)
#
# E:\Jupyter\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1367     if handle is None:
# -> 1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1369                            run_metadata)
#
# E:\Jupyter\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1393                     'disable_meta_optimizer = True')
# -> 1394       raise type(e)(node_def, op, message)
#    1395
#
# NotFoundError: Key bias_10 not found in checkpoint
# 	 [[node save_11/RestoreV2 (defined at <ipython-input-28-4cf973240306>:13) ]]
#
# Original stack trace for 'save_11/RestoreV2':
#   File "E:\Jupyter\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "E:\Jupyter\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "E:\Jupyter\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "E:\Jupyter\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "E:\Jupyter\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "E:\Jupyter\lib\site-packages\tornado\platform\asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "E:\Jupyter\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "E:\Jupyter\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "E:\Jupyter\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "E:\Jupyter\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "E:\Jupyter\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "E:\Jupyter\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "E:\Jupyter\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "E:\Jupyter\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "E:\Jupyter\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "E:\Jupyter\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 2866, in run_cell
#     result = self._run_cell(
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "E:\Jupyter\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 3071, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-28-4cf973240306>", line 13, in <module>
#     saver = tf.train.Saver() #저장된 모델을 초기화
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 835, in __init__
#     self.build()
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 847, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 875, in _build
#     self.saver_def = self._builder._build_internal(  # pylint: disable=protected-access
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 514, in _build_internal
#     restore_op = self._AddRestoreOps(filename_tensor, saveables,
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 334, in _AddRestoreOps
#     all_tensors = self.bulk_restore(filename_tensor, saveables, preferred_shard,
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 582, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1507, in restore_v2
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 748, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\framework\ops.py", line 3528, in _create_op_internal
#     ret = Operation(
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\framework\ops.py", line 1990, in __init__
#     self._traceback = tf_stack.extract_stack()
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# E:\Jupyter\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      68   try:
# ---> 69     return CheckpointReader.CheckpointReader_GetTensor(
#      70         self, compat.as_bytes(tensor_str))
#
# RuntimeError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1307       try:
# -> 1308         names_to_keys = object_graph_key_mapping(save_path)
#    1309       except errors.NotFoundError:
#
# E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py in object_graph_key_mapping(checkpoint_path)
#    1625   reader = py_checkpoint_reader.NewCheckpointReader(checkpoint_path)
# -> 1626   object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
#    1627   object_graph_proto = (trackable_object_graph_pb2.TrackableObjectGraph())
#
# E:\Jupyter\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      73   except RuntimeError as e:
# ---> 74     error_translator(e)
#      75
#
# E:\Jupyter\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in error_translator(e)
#      34       'matching files for') in error_message:
# ---> 35     raise errors_impl.NotFoundError(None, None, error_message)
#      36   elif 'Sliced checkpoints are not supported' in error_message or (
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-29-b17b9d14b61f> in <module>
#       3
#       4     save_path = "./saved.cpkt" #저장된 학습 모델
# ----> 5     saver.restore(sess, save_path) #해당 session에 저장된 학습 모델을 불러옴
#       6
#       7     data = ((avg_temp, min_temp, max_temp, rain_fall),) #user input을 이용하여 2차원 배열을 생성
#
# E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1311         # is a graph mismatch. Re-raise the original error with
#    1312         # a helpful message (b/110263146)
# -> 1313         raise _wrap_restore_error_with_msg(
#    1314             err, "a Variable name or other graph key that is missing")
#    1315
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key bias_10 not found in checkpoint
# 	 [[node save_11/RestoreV2 (defined at <ipython-input-28-4cf973240306>:13) ]]
#
# Original stack trace for 'save_11/RestoreV2':
#   File "E:\Jupyter\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "E:\Jupyter\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "E:\Jupyter\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "E:\Jupyter\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "E:\Jupyter\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "E:\Jupyter\lib\site-packages\tornado\platform\asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "E:\Jupyter\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "E:\Jupyter\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "E:\Jupyter\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "E:\Jupyter\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "E:\Jupyter\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "E:\Jupyter\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "E:\Jupyter\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "E:\Jupyter\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "E:\Jupyter\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "E:\Jupyter\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "E:\Jupyter\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 2866, in run_cell
#     result = self._run_cell(
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "E:\Jupyter\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 3071, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "E:\Jupyter\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-28-4cf973240306>", line 13, in <module>
#     saver = tf.train.Saver() #저장된 모델을 초기화
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 835, in __init__
#     self.build()
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 847, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 875, in _build
#     self.saver_def = self._builder._build_internal(  # pylint: disable=protected-access
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 514, in _build_internal
#     restore_op = self._AddRestoreOps(filename_tensor, saveables,
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 334, in _AddRestoreOps
#     all_tensors = self.bulk_restore(filename_tensor, saveables, preferred_shard,
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\training\saver.py", line 582, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1507, in restore_v2
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 748, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\framework\ops.py", line 3528, in _create_op_internal
#     ret = Operation(
#   File "E:\Jupyter\lib\site-packages\tensorflow\python\framework\ops.py", line 1990, in __init__
#     self._traceback = tf_stack.extract_stack()
